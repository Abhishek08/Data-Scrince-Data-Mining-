# %% [markdown]
# # Data Cleaning , Part 2  ( Using interpolation)

# %% [markdown]
# <span style="color:blue">
#
# - Interpolation is a technique in Python used to estimate unknown data points between two known data points.
#
# - Interpolation is mostly used to impute missing values in the dataframe or series while preprocessing data.
#
# - Interpolation is also used in Image Processing when expanding an image you can estimate the pixel value with help of neighboring pixels.
# </span>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({"A":[1,2,3,4,5,np.NaN,7,8,9]})

# %%
df
# Out:
#      A
# 0  1.0
# 1  2.0
# 2  3.0
# 3  4.0
# 4  5.0
# 5  NaN
# 6  7.0
# 7  8.0
# 8  9.0

# %%
df.isnull().sum()
# Out:
# A    1
# dtype: int64

# %%
df.interpolate() # Linear
# Out:
#      A
# 0  1.0
# 1  2.0
# 2  3.0
# 3  4.0
# 4  5.0
# 5  6.0
# 6  7.0
# 7  8.0
# 8  9.0

# %%
df = pd.read_csv('school.csv')

# %%
df
# Out:
#    Student ID    Math  English        Date
# 0           1    70.0     60.0  01/01/2022
# 1           2  9999.0     55.0  03/01/2022
# 2           3    45.0      NaN  04/01/2022
# 3           4    75.0     50.0  05/01/2022
# 4           5     NaN     75.0  08/01/2022
# 5           6    90.0      NaN  10/01/2012
# 6           7    95.0     80.0  11/01/2022
# 7           8     NaN     57.0  13/01/2022
# 8           9    80.0      NaN  15/01/2022
# 9          10     NaN     64.0  16/01/2022

# %%
df = df.replace(9999.0,np.NAN)

# %%
df
# Out:
#    Student ID  Math  English        Date
# 0           1  70.0     60.0  01/01/2022
# 1           2   NaN     55.0  03/01/2022
# 2           3  45.0      NaN  04/01/2022
# 3           4  75.0     50.0  05/01/2022
# 4           5   NaN     75.0  08/01/2022
# 5           6  90.0      NaN  10/01/2012
# 6           7  95.0     80.0  11/01/2022
# 7           8   NaN     57.0  13/01/2022
# 8           9  80.0      NaN  15/01/2022
# 9          10   NaN     64.0  16/01/2022

# %%
df.interpolate()  # Linear
# Out:
#    Student ID  Math  English        Date
# 0           1  70.0     60.0  01/01/2022
# 1           2  57.5     55.0  03/01/2022
# 2           3  45.0     52.5  04/01/2022
# 3           4  75.0     50.0  05/01/2022
# 4           5  82.5     75.0  08/01/2022
# 5           6  90.0     77.5  10/01/2012
# 6           7  95.0     80.0  11/01/2022
# 7           8  87.5     57.0  13/01/2022
# 8           9  80.0     60.5  15/01/2022
# 9          10  80.0     64.0  16/01/2022

# %%
df.interpolate(method='time')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20720/722817345.py in <module>
# ----> 1 df.interpolate(method='time')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10710         **kwargs,
#   10711     ) -> DataFrame | None:
# > 10712         return super().interpolate(
#   10713             method,
#   10714             axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6897                 "those NaNs before interpolating."
#    6898             )
# -> 6899         new_data = obj._mgr.interpolate(
#    6900             method=method,
#    6901             axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in interpolate(self, **kwargs)
#     375
#     376     def interpolate(self: T, **kwargs) -> T:
# --> 377         return self.apply("interpolate", **kwargs)
#     378
#     379     def shift(self: T, periods: int, axis: int, fill_value) -> T:
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in interpolate(self, method, axis, index, inplace, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#    1103         data = cast(np.ndarray, data)  # bc overridden by ExtensionBlock
#    1104
# -> 1105         interp_values = missing.interpolate_array_2d(
#    1106             data,
#    1107             method=method,
#
# ~\Anaconda3\lib\site-packages\pandas\core\missing.py in interpolate_array_2d(data, method, axis, index, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#     238         assert index is not None  # for mypy
#     239
# --> 240         interp_values = interpolate_2d_with_fill(
#     241             data=data,
#     242             index=index,
#
# ~\Anaconda3\lib\site-packages\pandas\core\missing.py in interpolate_2d_with_fill(data, index, axis, method, limit, limit_direction, limit_area, fill_value, **kwargs)
#     295
#     296     # interp each column independently
# --> 297     return np.apply_along_axis(func, axis, data)
#     298
#     299
#
# <__array_function__ internals> in apply_along_axis(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     377             'Cannot apply_along_axis when any iteration dimensions are 0'
#     378         ) from None
# --> 379     res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     380
#     381     # build a buffer for storing evaluations of func1d.
#
# ~\Anaconda3\lib\site-packages\pandas\core\missing.py in func(yvalues)
#     282         # should the axis argument be handled below in apply_along_axis?
#     283         # i.e. not an arg to interpolate_1d
# --> 284         return interpolate_1d(
#     285             xvalues=index,
#     286             yvalues=yvalues,
#
# ~\Anaconda3\lib\site-packages\pandas\core\missing.py in interpolate_1d(xvalues, yvalues, method, limit, limit_direction, limit_area, fill_value, bounds_error, order, **kwargs)
#     330     if method == "time":
#     331         if not needs_i8_conversion(xvalues.dtype):
# --> 332             raise ValueError(
#     333                 "time-weighted interpolation only works "
#     334                 "on Series or DataFrames with a "
#
# ValueError: time-weighted interpolation only works on Series or DataFrames with a DatetimeIndex

# %%
df.dtypes
# Out:
# Student ID      int64
# Math          float64
# English       float64
# Date           object
# dtype: object

# %%
df = pd.read_csv('school.csv', parse_dates=['Date'], index_col='Date')

# %%
df = df.replace(9999.0,np.NAN)

# %%
df
# Out:
#             Student ID  Math  English
# Date
# 2022-01-01           1  70.0     60.0
# 2022-03-01           2   NaN     55.0
# 2022-04-01           3  45.0      NaN
# 2022-05-01           4  75.0     50.0
# 2022-08-01           5   NaN     75.0
# 2012-10-01           6  90.0      NaN
# 2022-11-01           7  95.0     80.0
# 2022-01-13           8   NaN     57.0
# 2022-01-15           9  80.0      NaN
# 2022-01-16          10   NaN     64.0

# %%
df.interpolate(method='time')
# Out:
#             Student ID       Math    English
# Date
# 2022-01-01           1  70.000000  60.000000
# 2022-03-01           2  59.276316  55.000000
# 2022-04-01           3  45.000000  52.459016
# 2022-05-01           4  75.000000  50.000000
# 2022-08-01           5  85.000000  75.000000
# 2012-10-01           6  90.000000  60.000000
# 2022-11-01           7  95.000000  80.000000
# 2022-01-13           8  78.571429  57.000000
# 2022-01-15           9  80.000000  61.666667
# 2022-01-16          10  79.539474  64.000000

# %%
df.interpolate(method='nearest')
# Out:
#             Student ID  Math  English
# Date
# 2022-01-01           1  70.0     60.0
# 2022-03-01           2  45.0     55.0
# 2022-04-01           3  45.0     50.0
# 2022-05-01           4  75.0     50.0
# 2022-08-01           5  75.0     75.0
# 2012-10-01           6  90.0      NaN
# 2022-11-01           7  95.0     80.0
# 2022-01-13           8  80.0     57.0
# 2022-01-15           9  80.0     64.0
# 2022-01-16          10  80.0     64.0
